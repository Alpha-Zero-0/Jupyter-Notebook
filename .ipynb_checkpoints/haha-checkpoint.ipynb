# %% [markdown]
# ## Table of Contents
# 1. [Data Type](#Data-Type)

# %% [markdown]
# ## Data Type

# %%
type(12)
# Out:
# int

# %%
isinstance(12, int)
# Out:
# True

# %%
isinstance(12, (float, int))
# Out:
# True
